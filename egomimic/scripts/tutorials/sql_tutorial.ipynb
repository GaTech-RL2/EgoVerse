# %%
from sqlalchemy import (
    Boolean,
    Column,
    Float,
    Integer,
    MetaData,
    String,
    Table,
    text,
    update,
)

from egomimic.utils.aws.aws_sql import (
    TableRow,
    create_default_engine,
    episode_table_to_df,
)

# %%
engine = create_default_engine()
# Out:
# Tables in schema 'app': ['episodes']

# %%
df = episode_table_to_df(engine)
df
# Out:
#                    episode_hash                  operator    lab  num_frames  \
# 0      696bc6351cafc9f413b5b7e8  695d098f83a9fdf2d84d9a47  mecka      1960.0
# 1      696b2152d1aa1f60b4db5ef1  694a6ead5c0479a0fb867619  mecka      2700.0
# 2      696bcb732a9a68766920de81  696452cf83a9fdf2d86552c5  mecka      2252.0
# 3      69b4944484179943aec080c6  6948bbeb5c0479a0fb82ec42  mecka      2278.0
# 4      693cd014bec8abdc94f9a365  693369d4c195d3a38a24af5c  mecka      2650.0
# ...                         ...                       ...    ...         ...
# 58034  692ee049ef7557106e6c4b99  678d5c6368e425c008acaea5  mecka        66.0
# 58035  692ee046ef7557106e6c4b80  678d5c6368e425c008acaea5  mecka       110.0
# 58036  692eab58b8797912ff78a859  6768a79a7fdec9138007a095  mecka       113.0
# 58037  696bbd5575020a567fd376e9  6959d51cb8d0e4dc08fb48e1  mecka      3202.0
# 58038  692eaaa796d2056439f018ab  6768a79a7fdec9138007a095  mecka       114.0
#
#                         task  \
# 0           packaging_cloths
# 1      cleaning_engine_parts
# 2         folding_paper_bags
# 3          planting_cuttings
# 4              labeling_eggs
# ...                      ...
# 58034    object_in_container
# 58035    object_in_container
# 58036    object_in_container
# 58037       wick_preparation
# 58038    object_in_container
#
#                                         task_description            scene  \
# 0      In the final part of the video, the person con...        stockroom
# 1      A mechanic continues to clean a used, three-cy...      service_bay
# 2      A person begins folding a new paper bag, caref...   packaging_area
# 3      Planting plant cuttings into a tray filled wit...          nursery
# 4      The person uses a pair of scissors to cut labe...     packing_shed
# ...                                                  ...              ...
# 58034
# 58035
# 58036
# 58037  The person continues preparing candle wicks, c...  production_area
# 58038
#
#                                                  objects  \
# 0      ["plaid_cloths", "plastic_bags", "cardboard_bo...
# 1                ["engine_gasket", "workbench", "cloth"]
# 2      ["paper_sheet", "glue", "plastic_container", "...
# 3             ["soil", "plant_cuttings", "tray", "pots"]
# 4                      ["labels", "egg_cartons", "eggs"]
# ...                                                  ...
# 58034
# 58035
# 58036
# 58037  ["tealight_cup", "wooden_sticks", "wick", "met...
# 58038
#
#                                           processed_path  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 58034  s3://rldb/mecka/flagship/692ee049ef7557106e6c4...
# 58035  s3://rldb/mecka/flagship/692ee046ef7557106e6c4...
# 58036  s3://rldb/mecka/flagship/692eab58b8797912ff78a...
# 58037  s3://rldb/mecka/freeform/696bbd5575020a567fd376e9
# 58038  s3://rldb/mecka/flagship/692eaaa796d2056439f01...
#
#                                                 mp4_path  ...      robot_name  \
# 0                                                   None  ...  mecka_bimanual
# 1                                                   None  ...  mecka_bimanual
# 2                                                   None  ...  mecka_bimanual
# 3                                                   None  ...  mecka_bimanual
# 4                                                   None  ...  mecka_bimanual
# ...                                                  ...  ...             ...
# 58034  rldb:/mecka/flagship/692ee049ef7557106e6c4b99_...  ...  mecka_bimanual
# 58035  rldb:/mecka/flagship/692ee046ef7557106e6c4b80_...  ...  mecka_bimanual
# 58036  rldb:/mecka/flagship/692eab58b8797912ff78a859_...  ...  mecka_bimanual
# 58037  rldb:/mecka/freeform/696bbd5575020a567fd376e9_...  ...  mecka_bimanual
# 58038  rldb:/mecka/flagship/692eaaa796d2056439f018ab_...  ...  mecka_bimanual
#
#       is_eval eval_score  eval_success  processing_error  \
# 0       False       -1.0          True
# 1       False       -1.0          True
# 2       False       -1.0          True
# 3       False       -1.0          True
# 4       False       -1.0          True
# ...       ...        ...           ...               ...
# 58034   False       -1.0          True
# 58035   False       -1.0          True
# 58036   False       -1.0          True
# 58037   False       -1.0          True
# 58038   False       -1.0          True
#
#                                      zarr_processed_path  \
# 0      s3://rldb/processed_v3/mecka/freeform/696bc635...
# 1      s3://rldb/processed_v3/mecka/freeform/696b2152...
# 2      s3://rldb/processed_v3/mecka/freeform/696bcb73...
# 3      s3://rldb/processed_v3/mecka/freeform/69b49444...
# 4      s3://rldb/processed_v3/mecka/freeform/693cd014...
# ...                                                  ...
# 58034  s3://rldb/processed_v3/mecka/flagship/692ee049...
# 58035  s3://rldb/processed_v3/mecka/flagship/692ee046...
# 58036  s3://rldb/processed_v3/mecka/flagship/692eab58...
# 58037  s3://rldb/processed_v3/mecka/freeform/696bbd55...
# 58038  s3://rldb/processed_v3/mecka/flagship/692eaaa7...
#
#       zarr_processing_error  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...
# 58034
# 58035
# 58036
# 58037
# 58038
#
#                                            zarr_mp4_path       license  \
# 0      s3://rldb/processed_v3/mecka/freeform/696bc635...          None
# 1      s3://rldb/processed_v3/mecka/freeform/696b2152...          None
# 2      s3://rldb/processed_v3/mecka/freeform/696bcb73...          None
# 3      s3://rldb/processed_v3/mecka/freeform/69b49444...  CC BY-SA 4.0
# 4      s3://rldb/processed_v3/mecka/freeform/693cd014...          None
# ...                                                  ...           ...
# 58034  s3://rldb/processed_v3/mecka/flagship/692ee049...  CC BY-SA 4.0
# 58035  s3://rldb/processed_v3/mecka/flagship/692ee046...  CC BY-SA 4.0
# 58036  s3://rldb/processed_v3/mecka/flagship/692eab58...  CC BY-SA 4.0
# 58037  s3://rldb/processed_v3/mecka/freeform/696bbd55...  CC BY-SA 4.0
# 58038  s3://rldb/processed_v3/mecka/flagship/692eaaa7...  CC BY-SA 4.0
#
#                                                 segments
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      [{'label': 'adjust soil in container', 'end_se...
# 4                                                   None
# ...                                                  ...
# 58034                                               None
# 58035                                               None
# 58036                                               None
# 58037  [{'label': 'pick up sticks, align sticks', 'en...
# 58038                                               None
#
# [58039 rows x 22 columns]

# %%
# Filter to certain lab
len(df[df["task"] == "cup_on_saucer_success_1"])
# Out:
# 80

# %%
len(df[df["task"] == "cup_on_saucer_failure_1"])
# Out:
# 16

# %%
# Flagship Fold Clothes Data
df[(df["task"] == "fold_clothes") & df["lab"].isin(["rl2", "eth", "song", "wang"])]
