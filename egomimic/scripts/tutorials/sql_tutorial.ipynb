# %%
from sqlalchemy import (
    Boolean,
    Column,
    Float,
    Integer,
    MetaData,
    String,
    Table,
    text,
    update,
)

from egomimic.utils.aws.aws_sql import (
    TableRow,
    create_default_engine,
    episode_table_to_df,
)

# %%
engine = create_default_engine()
# Out:
# Tables in schema 'app': ['episodes']

# %%
df = episode_table_to_df(engine)
df
# Out:
# No rows found in table 'episodes'.
# Empty DataFrame
# Columns: [episode_hash, operator, task, embodiment, robot_name, num_frames, task_description, scene, objects, zarr_processed_path, zarr_mp4_path, zarr_processing_error, is_deleted, data_type]
# Index: []

# %%
# Filter to certain lab
df[df["lab"] == "rl2"]

# %%
# Flagship Fold Clothes Data
df[(df["task"] == "fold_clothes") & df["lab"].isin(["rl2", "eth", "song", "wang"])]
