# %%
from sqlalchemy import (
    Boolean,
    Column,
    Float,
    Integer,
    MetaData,
    String,
    Table,
    text,
    update,
)

from egomimic.utils.aws.aws_sql import (
    TableRow,
    create_default_engine,
    episode_table_to_df,
)

# %%
engine = create_default_engine()
# Out:
# Tables in schema 'app': ['episodes']

# %%
df = episode_table_to_df(engine)
df
# Out:
#                    episode_hash                  operator    lab  num_frames  \
# 0      696bc6351cafc9f413b5b7e8  695d098f83a9fdf2d84d9a47  mecka      1960.0
# 1      696b2152d1aa1f60b4db5ef1  694a6ead5c0479a0fb867619  mecka      2700.0
# 2      696bcb732a9a68766920de81  696452cf83a9fdf2d86552c5  mecka      2252.0
# 3      69b4944484179943aec080c6  6948bbeb5c0479a0fb82ec42  mecka      2278.0
# 4      693cd014bec8abdc94f9a365  693369d4c195d3a38a24af5c  mecka      2650.0
# ...                         ...                       ...    ...         ...
# 72259  696db125ddefc568d7372680  695b04fc83a9fdf2d8485831  mecka      2698.0
# 72260  696b9a50a04610abd4bb2ed0  694901865c0479a0fb833c40  mecka      2848.0
# 72261  696bac1d7e6f94bf3414388d  6951c933c0d9448524bb1d46  mecka      3598.0
# 72262  696babf5b17075c2c32fa74b  694c877362d08e8cd95f46fd  mecka      3598.0
# 72263  696bbd5575020a567fd376e9  6959d51cb8d0e4dc08fb48e1  mecka      3202.0
#
#                          task  \
# 0            packaging_cloths
# 1       cleaning_engine_parts
# 2          folding_paper_bags
# 3           planting_cuttings
# 4               labeling_eggs
# ...                       ...
# 72259         packaging_items
# 72260  decorating_party_horns
# 72261            making_kites
# 72262          cleaning_shoes
# 72263        wick_preparation
#
#                                         task_description             scene  \
# 0      In the final part of the video, the person con...         stockroom
# 1      A mechanic continues to clean a used, three-cy...       service_bay
# 2      A person begins folding a new paper bag, caref...    packaging_area
# 3      Planting plant cuttings into a tray filled wit...           nursery
# 4      The person uses a pair of scissors to cut labe...      packing_shed
# ...                                                  ...               ...
# 72259  A person is sitting and packaging small, black...  material_storage
# 72260  A person attaches a pre-made blue fringed pape...     craft_section
# 72261  A person continues to assemble a kite frame. T...     craft_section
# 72262  A person is using a brush and soapy water to s...      repair_bench
# 72263  The person continues preparing candle wicks, c...   production_area
#
#                                                  objects  \
# 0      ["plaid_cloths", "plastic_bags", "cardboard_bo...
# 1                ["engine_gasket", "workbench", "cloth"]
# 2      ["paper_sheet", "glue", "plastic_container", "...
# 3             ["soil", "plant_cuttings", "tray", "pots"]
# 4                      ["labels", "egg_cartons", "eggs"]
# ...                                                  ...
# 72259  ["air_stones", "plastic_bags", "cardboard_box"...
# 72260  ["party_horn", "blue_fringed_paper", "white_fr...
# 72261          ["kite_frame", "bamboo_sticks", "string"]
# 72262                            ["shoe", "soapy_water"]
# 72263  ["tealight_cup", "wooden_sticks", "wick", "met...
#
#                                           processed_path mp4_path  ...  \
# 0                                                   None     None  ...
# 1                                                   None     None  ...
# 2                                                   None     None  ...
# 3                                                   None     None  ...
# 4                                                   None     None  ...
# ...                                                  ...      ...  ...
# 72259  s3://rldb/mecka/freeform/696db125ddefc568d7372680     None  ...
# 72260  s3://rldb/mecka/freeform/696b9a50a04610abd4bb2ed0     None  ...
# 72261  s3://rldb/mecka/freeform/696bac1d7e6f94bf3414388d     None  ...
# 72262  s3://rldb/mecka/freeform/696babf5b17075c2c32fa74b     None  ...
# 72263  s3://rldb/mecka/freeform/696bbd5575020a567fd376e9     None  ...
#
#            robot_name is_eval eval_score  eval_success  processing_error  \
# 0      mecka_bimanual   False       -1.0          True
# 1      mecka_bimanual   False       -1.0          True
# 2      mecka_bimanual   False       -1.0          True
# 3      mecka_bimanual   False       -1.0          True
# 4      mecka_bimanual   False       -1.0          True
# ...               ...     ...        ...           ...               ...
# 72259  mecka_bimanual   False       -1.0          True
# 72260  mecka_bimanual   False       -1.0          True
# 72261  mecka_bimanual   False       -1.0          True
# 72262  mecka_bimanual   False       -1.0          True
# 72263  mecka_bimanual   False       -1.0          True
#
#                                      zarr_processed_path  \
# 0      s3://rldb/processed_v3/mecka/freeform/696bc635...
# 1      s3://rldb/processed_v3/mecka/freeform/696b2152...
# 2      s3://rldb/processed_v3/mecka/freeform/696bcb73...
# 3      s3://rldb/processed_v3/mecka/freeform/69b49444...
# 4      s3://rldb/processed_v3/mecka/freeform/693cd014...
# ...                                                  ...
# 72259  s3://rldb/processed_v3/mecka/freeform/696db125...
# 72260  s3://rldb/processed_v3/mecka/freeform/696b9a50...
# 72261  s3://rldb/processed_v3/mecka/freeform/696bac1d...
# 72262  s3://rldb/processed_v3/mecka/freeform/696babf5...
# 72263  s3://rldb/processed_v3/mecka/freeform/696bbd55...
#
#       zarr_processing_error  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...
# 72259
# 72260
# 72261
# 72262
# 72263
#
#                                            zarr_mp4_path       license  \
# 0      s3://rldb/processed_v3/mecka/freeform/696bc635...          None
# 1      s3://rldb/processed_v3/mecka/freeform/696b2152...          None
# 2      s3://rldb/processed_v3/mecka/freeform/696bcb73...          None
# 3      s3://rldb/processed_v3/mecka/freeform/69b49444...  CC BY-SA 4.0
# 4      s3://rldb/processed_v3/mecka/freeform/693cd014...          None
# ...                                                  ...           ...
# 72259  s3://rldb/processed_v3/mecka/freeform/696db125...  CC BY-SA 4.0
# 72260  s3://rldb/processed_v3/mecka/freeform/696b9a50...  CC BY-SA 4.0
# 72261  s3://rldb/processed_v3/mecka/freeform/696bac1d...  CC BY-SA 4.0
# 72262  s3://rldb/processed_v3/mecka/freeform/696babf5...  CC BY-SA 4.0
# 72263  s3://rldb/processed_v3/mecka/freeform/696bbd55...  CC BY-SA 4.0
#
#                                                 segments
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      [{'label': 'adjust soil in container', 'end_se...
# 4                                                   None
# ...                                                  ...
# 72259  [{'label': 'pick up plastic bag, pick up grey ...
# 72260  [{'label': 'wrap fringe, adjust cone', 'end_se...
# 72261  [{'label': 'tie two wooden sticks to form a cr...
# 72262  [{'label': 'hold shoe, scrub shoe with brush',...
# 72263  [{'label': 'pick up sticks, align sticks', 'en...
#
# [72264 rows x 22 columns]

# %%
# Filter to certain lab
df[df["lab"] == "mecka"]
# Out:
#                    episode_hash                  operator    lab  num_frames  \
# 0      696bc6351cafc9f413b5b7e8  695d098f83a9fdf2d84d9a47  mecka      1960.0
# 1      696b2152d1aa1f60b4db5ef1  694a6ead5c0479a0fb867619  mecka      2700.0
# 2      696bcb732a9a68766920de81  696452cf83a9fdf2d86552c5  mecka      2252.0
# 3      69b4944484179943aec080c6  6948bbeb5c0479a0fb82ec42  mecka      2278.0
# 4      693cd014bec8abdc94f9a365  693369d4c195d3a38a24af5c  mecka      2650.0
# ...                         ...                       ...    ...         ...
# 72259  696db125ddefc568d7372680  695b04fc83a9fdf2d8485831  mecka      2698.0
# 72260  696b9a50a04610abd4bb2ed0  694901865c0479a0fb833c40  mecka      2848.0
# 72261  696bac1d7e6f94bf3414388d  6951c933c0d9448524bb1d46  mecka      3598.0
# 72262  696babf5b17075c2c32fa74b  694c877362d08e8cd95f46fd  mecka      3598.0
# 72263  696bbd5575020a567fd376e9  6959d51cb8d0e4dc08fb48e1  mecka      3202.0
#
#                          task  \
# 0            packaging_cloths
# 1       cleaning_engine_parts
# 2          folding_paper_bags
# 3           planting_cuttings
# 4               labeling_eggs
# ...                       ...
# 72259         packaging_items
# 72260  decorating_party_horns
# 72261            making_kites
# 72262          cleaning_shoes
# 72263        wick_preparation
#
#                                         task_description             scene  \
# 0      In the final part of the video, the person con...         stockroom
# 1      A mechanic continues to clean a used, three-cy...       service_bay
# 2      A person begins folding a new paper bag, caref...    packaging_area
# 3      Planting plant cuttings into a tray filled wit...           nursery
# 4      The person uses a pair of scissors to cut labe...      packing_shed
# ...                                                  ...               ...
# 72259  A person is sitting and packaging small, black...  material_storage
# 72260  A person attaches a pre-made blue fringed pape...     craft_section
# 72261  A person continues to assemble a kite frame. T...     craft_section
# 72262  A person is using a brush and soapy water to s...      repair_bench
# 72263  The person continues preparing candle wicks, c...   production_area
#
#                                                  objects  \
# 0      ["plaid_cloths", "plastic_bags", "cardboard_bo...
# 1                ["engine_gasket", "workbench", "cloth"]
# 2      ["paper_sheet", "glue", "plastic_container", "...
# 3             ["soil", "plant_cuttings", "tray", "pots"]
# 4                      ["labels", "egg_cartons", "eggs"]
# ...                                                  ...
# 72259  ["air_stones", "plastic_bags", "cardboard_box"...
# 72260  ["party_horn", "blue_fringed_paper", "white_fr...
# 72261          ["kite_frame", "bamboo_sticks", "string"]
# 72262                            ["shoe", "soapy_water"]
# 72263  ["tealight_cup", "wooden_sticks", "wick", "met...
#
#                                           processed_path mp4_path  ...  \
# 0                                                   None     None  ...
# 1                                                   None     None  ...
# 2                                                   None     None  ...
# 3                                                   None     None  ...
# 4                                                   None     None  ...
# ...                                                  ...      ...  ...
# 72259  s3://rldb/mecka/freeform/696db125ddefc568d7372680     None  ...
# 72260  s3://rldb/mecka/freeform/696b9a50a04610abd4bb2ed0     None  ...
# 72261  s3://rldb/mecka/freeform/696bac1d7e6f94bf3414388d     None  ...
# 72262  s3://rldb/mecka/freeform/696babf5b17075c2c32fa74b     None  ...
# 72263  s3://rldb/mecka/freeform/696bbd5575020a567fd376e9     None  ...
#
#            robot_name is_eval eval_score  eval_success  processing_error  \
# 0      mecka_bimanual   False       -1.0          True
# 1      mecka_bimanual   False       -1.0          True
# 2      mecka_bimanual   False       -1.0          True
# 3      mecka_bimanual   False       -1.0          True
# 4      mecka_bimanual   False       -1.0          True
# ...               ...     ...        ...           ...               ...
# 72259  mecka_bimanual   False       -1.0          True
# 72260  mecka_bimanual   False       -1.0          True
# 72261  mecka_bimanual   False       -1.0          True
# 72262  mecka_bimanual   False       -1.0          True
# 72263  mecka_bimanual   False       -1.0          True
#
#                                      zarr_processed_path  \
# 0      s3://rldb/processed_v3/mecka/freeform/696bc635...
# 1      s3://rldb/processed_v3/mecka/freeform/696b2152...
# 2      s3://rldb/processed_v3/mecka/freeform/696bcb73...
# 3      s3://rldb/processed_v3/mecka/freeform/69b49444...
# 4      s3://rldb/processed_v3/mecka/freeform/693cd014...
# ...                                                  ...
# 72259  s3://rldb/processed_v3/mecka/freeform/696db125...
# 72260  s3://rldb/processed_v3/mecka/freeform/696b9a50...
# 72261  s3://rldb/processed_v3/mecka/freeform/696bac1d...
# 72262  s3://rldb/processed_v3/mecka/freeform/696babf5...
# 72263  s3://rldb/processed_v3/mecka/freeform/696bbd55...
#
#       zarr_processing_error  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...
# 72259
# 72260
# 72261
# 72262
# 72263
#
#                                            zarr_mp4_path       license  \
# 0      s3://rldb/processed_v3/mecka/freeform/696bc635...          None
# 1      s3://rldb/processed_v3/mecka/freeform/696b2152...          None
# 2      s3://rldb/processed_v3/mecka/freeform/696bcb73...          None
# 3      s3://rldb/processed_v3/mecka/freeform/69b49444...  CC BY-SA 4.0
# 4      s3://rldb/processed_v3/mecka/freeform/693cd014...          None
# ...                                                  ...           ...
# 72259  s3://rldb/processed_v3/mecka/freeform/696db125...  CC BY-SA 4.0
# 72260  s3://rldb/processed_v3/mecka/freeform/696b9a50...  CC BY-SA 4.0
# 72261  s3://rldb/processed_v3/mecka/freeform/696bac1d...  CC BY-SA 4.0
# 72262  s3://rldb/processed_v3/mecka/freeform/696babf5...  CC BY-SA 4.0
# 72263  s3://rldb/processed_v3/mecka/freeform/696bbd55...  CC BY-SA 4.0
#
#                                                 segments
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      [{'label': 'adjust soil in container', 'end_se...
# 4                                                   None
# ...                                                  ...
# 72259  [{'label': 'pick up plastic bag, pick up grey ...
# 72260  [{'label': 'wrap fringe, adjust cone', 'end_se...
# 72261  [{'label': 'tie two wooden sticks to form a cr...
# 72262  [{'label': 'hold shoe, scrub shoe with brush',...
# 72263  [{'label': 'pick up sticks, align sticks', 'en...
#
# [41617 rows x 22 columns]

# %%
# Flagship Fold Clothes Data
df[(df["task"] == "fold_clothes") & df["lab"].isin(["rl2", "eth", "song", "wang"])]
