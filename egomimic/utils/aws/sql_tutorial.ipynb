# %%
from sqlalchemy import (
    Boolean,
    Column,
    Float,
    Integer,
    MetaData,
    String,
    Table,
    text,
    update,
)

from egomimic.utils.aws.aws_sql import (
    TableRow,
    create_default_engine,
    episode_table_to_df,
)

# %%
engine = create_default_engine()
# Out:
# Using hardcoded DB Credentials (ok for local testing)
# Tables in schema 'app': ['episodes']

# %%
df = episode_table_to_df(engine)
df
# Out:
#                      episode_hash                  operator    lab  \
# 0      2025-12-26-02-36-20-973000                      Ryan    rl2
# 1      2025-10-13-03-51-22-623000                      Elmo    rl2
# 2      2025-11-13-01-14-53-715000                      elmo    rl2
# 3        696bcd781894fc36a07d8ffb  695ef4da83a9fdf2d854f455  mecka
# 4        696ba3a636602141d44d6b94  6938404ec67c9e4814aecc35  mecka
# ...                           ...                       ...    ...
# 80117    696d31731b5841990138a1a6  6954e684d4a59e565ff4243d  mecka
# 80118    696d9ef62db0183ebc4d997e  6947d3395c0479a0fb81a78a  mecka
# 80119    696bbd5575020a567fd376e9  6959d51cb8d0e4dc08fb48e1  mecka
# 80120    696ba419cd29fb97fb107c4d  6948c2dd5c0479a0fb82f219  mecka
# 80121    696bb837dae7f926421a6144  6947d3395c0479a0fb81a78a  mecka
#
#        num_frames                 task  \
# 0          1295.0        cup_on_saucer
# 1          1700.0         fold_clothes
# 2            -1.0        move_caprisun
# 3          3148.0   packaging_products
# 4          2998.0    bottling_perfumes
# ...           ...                  ...
# 80117      2998.0       bottling_beads
# 80118      2698.0  packaging_cosmetics
# 80119      3202.0     wick_preparation
# 80120      3010.0   packaging_supplies
# 80121      3598.0   packaging_products
#
#                                         task_description               scene  \
# 0      pick up cup with one arm, hand it over to the ...                   1
# 1                                        folding clothes                  16
# 2      move caprison from one fixed region to another...              scene2
# 3      A person continues the packaging process by as...           stockroom
# 4      A person is bottling a mixed perfume by drawin...     testing_counter
# ...                                                  ...                 ...
# 80117  A person continues the repetitive task of scoo...       craft_section
# 80118  A person is packaging small, round, traditiona...  demonstration_area
# 80119  The person continues preparing candle wicks, c...     production_area
# 80120  A person sits on a tiled floor, sorting throug...           stockroom
# 80121  A person is manually packaging small, round, t...           stockroom
#
#                                                  objects  \
# 0                          {"white cup","yellow saucer"}
# 1      {"short sleeve shirts","long sleeve shirts",sh...
# 2                                             {caprisun}
# 3                      ["boxes", "plastic_bags", "tape"]
# 4      ["graduated_cylinder", "roll-on_bottle", "perf...
# ...                                                  ...
# 80117                        ["beads", "bowl", "bottle"]
# 80118  ["plastic_cups", "lids", "cosmetic_powders", "...
# 80119  ["tealight_cup", "wooden_sticks", "wick", "met...
# 80120  ["popsicle_sticks", "plastic_bag", "cardboard_...
# 80121  ["plastic_containers", "herbal_tablets", "stic...
#
#                                           processed_path  \
# 0      s3://rldb/processed_v2/eva/2025-12-26-02-36-20...
# 1      s3://rldb/processed_v2/aria/2025-10-13-03-51-2...
# 2
# 3      s3://rldb/mecka/freeform/696bcd781894fc36a07d8...
# 4      s3://rldb/mecka/freeform/696ba3a636602141d44d6...
# ...                                                  ...
# 80117  s3://rldb/mecka/freeform/696d31731b5841990138a1a6
# 80118  s3://rldb/mecka/freeform/696d9ef62db0183ebc4d997e
# 80119  s3://rldb/mecka/freeform/696bbd5575020a567fd376e9
# 80120  s3://rldb/mecka/freeform/696ba419cd29fb97fb107c4d
# 80121  s3://rldb/mecka/freeform/696bb837dae7f926421a6144
#
#                                                 mp4_path  is_deleted  \
# 0      s3://rldb/processed_v2/eva/1766716580973_video...       False
# 1      s3://rldb/processed_v2/aria/1760327482623_vide...       False
# 2                                                               True
# 3      rldb:/mecka/freeform/696bcd781894fc36a07d8ffb_...       False
# 4      rldb:/mecka/freeform/696ba3a636602141d44d6b94_...       False
# ...                                                  ...         ...
# 80117  rldb:/mecka/freeform/696d31731b5841990138a1a6_...       False
# 80118  rldb:/mecka/freeform/696d9ef62db0183ebc4d997e_...       False
# 80119  rldb:/mecka/freeform/696bbd5575020a567fd376e9_...       False
# 80120  rldb:/mecka/freeform/696ba419cd29fb97fb107c4d_...       False
# 80121  rldb:/mecka/freeform/696bb837dae7f926421a6144_...       False
#
#       embodiment      robot_name  is_eval  eval_score  eval_success  \
# 0            eva    eva_bimanual    False        -1.0          True
# 1           aria   aria_bimanual    False        -1.0          True
# 2            eva             eva    False        -1.0          True
# 3          mecka  mecka_bimanual    False        -1.0          True
# 4          mecka  mecka_bimanual    False        -1.0          True
# ...          ...             ...      ...         ...           ...
# 80117      mecka  mecka_bimanual    False        -1.0          True
# 80118      mecka  mecka_bimanual    False        -1.0          True
# 80119      mecka  mecka_bimanual    False        -1.0          True
# 80120      mecka  mecka_bimanual    False        -1.0          True
# 80121      mecka  mecka_bimanual    False        -1.0          True
#
#       processing_error zarr_processed_path zarr_processing_error
# 0
# 1
# 2
# 3
# 4
# ...                ...                 ...                   ...
# 80117
# 80118
# 80119
# 80120
# 80121
#
# [80122 rows x 19 columns]

# %% [markdown]
# ## Example Useful Functions

# %%
# Add Episode Test
episode = TableRow(
    episode_hash=1761408819,
    operator="test",
    lab="lab-x",
    num_frames=-1,
    task="bimanual_test",
    task_description="Dummy row for table inspection",
    scene="kitchen",
    objects="cup,plate,spoon",
    processed_path="",
    zarr_processed_path="",
    zarr_processing_error="",
    zarr_mp4_path="",
    mp4_path="",
    embodiment="aria",
    robot_name="",
    is_eval=False,
    eval_score=0.0,
    eval_success=False,
)
# Adding an episode
# add_episode(engine, episode)

# Update Episode Test
# episode.operator = "simar"
# update_episode(engine, episode)

# Get Table Row from Episode Hash
# episode_hash_to_table_row(engine, 123456)

# Delete episodes by hash
# delete_episodes(engine, [123456, 123457])

# %%
def drop_table(table_name):
    with engine.connect() as connection:
        connection.execute(text(f"DROP TABLE IF EXISTS app.{table_name} CASCADE;"))
        connection.commit()
    print(f"Dropped table '{table_name}' from schema 'app' if it existed.")

# %%
def create_table():
    metadata = MetaData(schema="app")

    Table(
        "episodes",
        metadata,
        Column("episode_hash", String, primary_key=True),
        Column("operator", String),
        Column("lab", String),
        Column("num_frames", Integer),
        Column("task", String),
        Column("task_description", String),
        Column("scene", String),
        Column(
            "objects", String
        ),  # Store as JSON or comma-separated list of object names
        Column("processed_path", String),
        Column("zarr_processed_path", String),
        Column("zarr_processing_error", String),
        Column("zarr_mp4_path", String),
        Column("mp4_path", String),
        Column("is_deleted", Boolean),
        Column("embodiment", String),
        Column("robot_name", String),
        Column("is_eval", Boolean),
        Column("eval_score", Float),
        Column("eval_success", Boolean),
    )

    metadata.create_all(engine)
    print("Created table 'episodes' in schema 'app'.")

# %%
def delete_episodes_by_task(task_name: str):
    episodes_tbl = Table("episodes", MetaData(), autoload_with=engine, schema="app")
    stmt = (
        update(episodes_tbl)
        .where(episodes_tbl.c.task == task_name)
        .values(is_deleted=True)
    )
    with engine.begin() as conn:
        conn.execute(stmt)
